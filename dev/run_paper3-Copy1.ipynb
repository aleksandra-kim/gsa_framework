# %%
import numpy as np
from pathlib import Path
import bw2data as bd
import bw2calc as bc
import stats_arrays as sa
import scipy.stats as stats
from gsa_framework.utils import read_pickle, write_pickle
from gsa_framework.models.life_cycle_assessment import LCAModel
from dev.utils_graph_traversal import filter_uncertain_technosphere_exchanges

from dev.utils_local_sa import get_bio_params_local_sa, get_cf_params_local_sa, get_tech_params_local_sa

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
if __name__ == "__main__":

#     path_base = Path(
#         "/Users/akim/PycharmProjects/gsa-framework-master/dev/write_files/"
#     )
    path_base = Path('/data/user/kim_a/protocol_gsa')
    write_dir = path_base 
    write_dir_sct = write_dir / "supply_chain_paper3"
    write_dir_sct.mkdir(exist_ok=True,parents=True)

    bd.projects.set_current("GSA for protocol")
    co = bd.Database("CH consumption 1.0")
    demand_act = [act for act in co if "Food" in act["name"]]
    assert len(demand_act) == 1
    demand_act = demand_act[0]
    demand = {demand_act: 1}
    uncertain_method = ("IPCC 2013", "climate change", "GWP 100a", "uncertain")
    lca = bc.LCA(demand, uncertain_method)
    lca.lci()
    lca.lcia()
    print(lca.score)
    
    # Technosphere
    max_calc = 1e+14
    cutoff = 1e-14
    tech_params_sct_filename = "tech_params_cutoff{:1.0e}_maxcalc{:1.0e}.pickle".format(cutoff, int(max_calc))
    tech_params_sct_filepath = write_dir_sct / tech_params_sct_filename
    if not tech_params_sct_filepath.exists():
        tech_params_sct = filter_uncertain_technosphere_exchanges(lca, cutoff=cutoff, max_calc=max_calc)
        write_pickle(tech_params_sct, tech_params_sct_filepath)
    else:
        tech_params_sct = read_pickle(tech_params_sct_filepath)
# Out:
# 211.57670115973556

# %%
def add_uncertainty_measure(params, q_range=0.95):
    """Generate uncertainty measures for all params."""

    from stats_arrays import MCRandomNumberGenerator

    mc = MCRandomNumberGenerator(params)
    params = params[mc.ordering]
    
    dt = np.dtype([
        ('row', '<u4'), 
        ('col', '<u4'), 
        ('std2mean', '<f4'), 
        ('std2mean_maxnormalized', '<f4'), 
#         ('var2mean', '<f4'), 
#         ('range2mean', '<f4'), 
        ('uncertainty_type', 'u1'),
        ('contribution', '<f4'),
        ('contribution_maxnormalized', '<f4'),
    ])

    params_uncertainty_measure = np.zeros(len(params), dtype=dt)
    
    q_low = (1-q_range)/2
    q_high = q_low + q_range

    offset = 0
    for uncertainty_type in mc.choices:
        numparams = mc.positions[uncertainty_type]
        if not numparams:
            continue
        current_params = params[offset:numparams + offset]
        params_uncertainty_measure[offset:numparams + offset]['row'] = current_params['row']
        params_uncertainty_measure[offset:numparams + offset]['col'] = current_params['col']
        params_uncertainty_measure[offset:numparams + offset]['uncertainty_type'] = \
            current_params['uncertainty_type']
        if uncertainty_type == sa.LognormalUncertainty:
            s_normal = current_params['scale']
            m_normal = current_params['loc']
            s = np.sqrt( (np.exp(s_normal**2)-1) * np.exp(2*m_normal + s_normal**2) )
            s = s_normal
            m = np.exp(m_normal + (s_normal**2)/2)
            range_ = stats.lognorm.ppf(q_high,s=s_normal, scale=np.exp(m_normal)) - \
                     stats.lognorm.ppf(q_low, s=s_normal, scale=np.exp(m_normal))
        elif uncertainty_type == sa.NormalUncertainty:
            s = current_params['scale']
            m = current_params['loc']
            range_ = stats.norm.ppf(q_high, loc=m, scale=s) - stats.norm.ppf(q_low, loc=m, scale=s)
        elif uncertainty_type == sa.UniformUncertainty:
            min_ = current_params['minimum']
            max_ = current_params['maximum']
            diff = max_ - min_
            s = diff / np.sqrt(12)
            m = current_params['loc']
            range_ = stats.uniform.ppf(q_high, loc=min_, scale=diff) - stats.uniform.ppf(q_low, loc=min_, scale=diff)
        elif uncertainty_type == sa.TriangularUncertainty:
            a = current_params['minimum']
            b = current_params['maximum']
            c = current_params['loc']
            diff = b - a
            m = (a+b+c)/3
            s = np.sqrt((a**2 + b**2 + c**2 - a*b - b*c - a*c)/18)
            range_ = stats.triang.ppf(q_high, c=(c-a)/diff, loc=a, scale=diff) - \
                     stats.triang.ppf(q_low,  c=(c-a)/diff, loc=a, scale=diff)
        else:
            offset += numparams
            continue

        params_uncertainty_measure[offset:numparams + offset]['std2mean'] = np.abs(s/m)
#         params_uncertainty_measure[offset:numparams + offset]['var2mean'] = np.abs((s**2)/m)
#         params_uncertainty_measure[offset:numparams + offset]['range2mean'] = np.abs(range_/m)

        offset += numparams

    params_uncertainty_measure = params_uncertainty_measure[np.argsort(mc.ordering)]
    
    return params_uncertainty_measure

# %%
dt = np.dtype([
    ('row', '<u4'), 
    ('col', '<u4'),
])

params_row_col = np.zeros(len(lca.tech_params), dt)
params_row_col[['row', 'col']] = [(p['row'], p['col']) for p in lca.tech_params]

tech_params_sct_row_col = np.zeros(len(tech_params_sct), dt)
tech_params_sct_row_col[['row', 'col']] = [(p[0], p[1]) for p in tech_params_sct]

where_inds = np.where(np.in1d(params_row_col, tech_params_sct_row_col))[0]
input_params = lca.tech_params[where_inds]

params_uncertain = add_uncertainty_measure(input_params)
order = np.argsort(params_uncertain['std2mean'])[-1::-1]

# num_params = -1
selected_tech_params = params_uncertain[order]

tech_params_sct_dict = {(p[0], p[1]): p[2] for p in tech_params_sct}
for p in selected_tech_params:
    p['contribution'] = tech_params_sct_dict[(p['row'], p['col'])]
selected_tech_params['std2mean_maxnormalized'] = \
    selected_tech_params['std2mean'] / max(selected_tech_params['std2mean'])
selected_tech_params['contribution_maxnormalized'] = \
    selected_tech_params['contribution'] / max(selected_tech_params['contribution'])

uncertainty_measure = 0*selected_tech_params['std2mean'] + 1*selected_tech_params['contribution']

num_params = 200
selected_tech_params_sorted = selected_tech_params[np.argsort(uncertainty_measure)[-1::-1][:num_params]]

where_selected_tech = where_inds[order][np.argsort(uncertainty_measure)[-1::-1][:num_params]]
where_selected_tech.sort()

# %% [markdown]
# # Local SA

# %%
# %%time 

const_factors = [1/10, 10]

# Technosphere
tech_params_c = get_tech_params_local_sa(
    where_selected_tech, 
    lca, 
    write_dir_sct, 
    const_factors, 
    tag="sct{}".format(num_params),
)

# Biosphere    
bio_params_c = get_bio_params_local_sa(lca, write_dir_sct, const_factors)

# Characterization
cf_params_c = get_cf_params_local_sa(lca, write_dir_sct, const_factors)
# Out:
# CPU times: user 25min 11s, sys: 47.6 s, total: 25min 58s
# Wall time: 2min 37s

# %% [markdown]
# # Validation

# %%
tech_params_c
# Out:
# {21098: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ff04e72f0621a2684d4da40f3a07658d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'b98c7b2cc3bfa5d3aac52040013a4b93'),
#   'scores': array([208.58131681, 241.53054462])},
#  21101: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ff04e72f0621a2684d4da40f3a07658d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'b90a6e04c5884bf9014f3c8efe5300af'),
#   'scores': array([208.43303649, 243.01334788])},
#  21104: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ff04e72f0621a2684d4da40f3a07658d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '72ec169c3addd2e5fc3661c256c0c93a'),
#   'scores': array([211.19255742, 216.18238655])},
#  21291: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2cb1c4859a7f7c51144c1aefff2e41a7'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd914569cfeb9d964ad05991cec83f52b'),
#   'scores': array([210.95063154, 217.90838843])},
#  22287: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8105136dfbc27d65cd74eb6482b24b3d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '0d50bed0ce9f5cc81ac2e75b0e72f321'),
#   'scores': array([207.49311763, 252.41253642])},
#  22292: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8105136dfbc27d65cd74eb6482b24b3d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'e4a680bd7f29474455652ff3ca34892d'),
#   'scores': array([208.44019355, 242.94177721])},
#  23013: {'input': ('ecoinvent 3.7.1 cutoff',
#    '457747605ee37bf8083c2097924212a7'),
#   'output': ('ecoinvent 3.7.1 cutoff', '8594c5a9d26f8ceaa9dff72caacaa1db'),
#   'scores': array([210.55905326, 221.94802083])},
#  27354: {'input': ('ecoinvent 3.7.1 cutoff',
#    'bf71c97595babc8c922f725129a4b70c'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd1c90c027d7c93ae6979151dc3e676d6'),
#   'scores': array([211.27260108, 214.61941021])},
#  28867: {'input': ('ecoinvent 3.7.1 cutoff',
#    'c9cc5bdcffed4a93b17f901eda2efff8'),
#   'output': ('ecoinvent 3.7.1 cutoff', '29dd00ee00b0e2027b875ebb83f844d1'),
#   'scores': array([207.75058476, 249.85847585])},
#  29794: {'input': ('ecoinvent 3.7.1 cutoff',
#    'dbb5ce3cecf802dd0433464bbd3ad4b9'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fc8f95407648786e771a5b82ddd943fc'),
#   'scores': array([211.23978714, 214.94704836])},
#  29868: {'input': ('ecoinvent 3.7.1 cutoff',
#    'dbb5ce3cecf802dd0433464bbd3ad4b9'),
#   'output': ('ecoinvent 3.7.1 cutoff', '859353ae6268a3f6f8b64f7493f2a525'),
#   'scores': array([210.40301501, 223.31569082])},
#  29954: {'input': ('ecoinvent 3.7.1 cutoff',
#    'dbb5ce3cecf802dd0433464bbd3ad4b9'),
#   'output': ('ecoinvent 3.7.1 cutoff', '2bdd7e0dd0c8e87fc7545a6db644f62a'),
#   'scores': array([211.26531854, 214.69109224])},
#  32966: {'input': ('ecoinvent 3.7.1 cutoff',
#    '1927e0c216cb9c438d5b7aeb0b4229a5'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1b66e26238e2dc9dffb8a1df12492d94'),
#   'scores': array([210.93854534, 217.95882884])},
#  33276: {'input': ('ecoinvent 3.7.1 cutoff',
#    'f1d49007888152d1dee06d36595241d0'),
#   'output': ('ecoinvent 3.7.1 cutoff', '56840ef285e3ad3f99a30d1dc2f4f3fe'),
#   'scores': array([211.227557  , 215.06814274])},
#  35647: {'input': ('ecoinvent 3.7.1 cutoff',
#    '589736930b8066148727ed24384ca204'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([211.13768668, 215.96684596])},
#  37895: {'input': ('ecoinvent 3.7.1 cutoff',
#    '7d7bc6c1533032748e8a3540abb7df21'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6273d44460968ecd729d9f92573081c3'),
#   'scores': array([211.1344956 , 215.99875672])},
#  41732: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a5f704070a2a1857413ac5471c02d2bc'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cee516150ebdd3126b77b893b38ec80d'),
#   'scores': array([211.05694912, 216.77422153])},
#  42344: {'input': ('ecoinvent 3.7.1 cutoff',
#    '342e2064251179cda5e58f086ee06c8b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'b6ee929fe7a4eb115d05c1029a53b309'),
#   'scores': array([211.00108941, 217.36607066])},
#  42520: {'input': ('ecoinvent 3.7.1 cutoff',
#    '0da038aca9ca47db23e99e01a2aba0e7'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f8e983cfb0b5ac53ae7b8cd91596376e'),
#   'scores': array([210.44360596, 222.90765317])},
#  48771: {'input': ('ecoinvent 3.7.1 cutoff',
#    '73c52ef52d928f9a6bd5bdc5bb7bce8d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '0bb601b14e82bf6bde60d357cd78a9f5'),
#   'scores': array([210.52184879, 222.61825827])},
#  49677: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a85a21b99210394e1e684c8c4ae7471f'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([208.92347028, 238.10900997])},
#  49715: {'input': ('ecoinvent 3.7.1 cutoff',
#    '31dc9798f0d62a062dd680873b652a59'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd8433387897459cb3059970b22e0110c'),
#   'scores': array([210.85569691, 218.78702666])},
#  49735: {'input': ('ecoinvent 3.7.1 cutoff',
#    '31dc9798f0d62a062dd680873b652a59'),
#   'output': ('ecoinvent 3.7.1 cutoff', '82b46dfca0b864b5c97fe7e486400524'),
#   'scores': array([211.24951237, 214.93429504])},
#  51014: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b064eef7f1b4a2f2a61caeca1492b7f0'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([208.69590976, 240.38461514])},
#  54170: {'input': ('ecoinvent 3.7.1 cutoff',
#    '9af1f77f96b1f8d082ad7685b6e568c5'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fa6c7358d8beeb638651cbb032c7a1c1'),
#   'scores': array([211.13336257, 216.01008705])},
#  54171: {'input': ('ecoinvent 3.7.1 cutoff',
#    '9af1f77f96b1f8d082ad7685b6e568c5'),
#   'output': ('ecoinvent 3.7.1 cutoff', '56473f6d07e1bad8134f8614efcab776'),
#   'scores': array([211.06448411, 216.69887168])},
#  56254: {'input': ('ecoinvent 3.7.1 cutoff',
#    '219bd599683f6a8041fd366ac336be3e'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'db048d933037fa0d6db66f0c8fd2af19'),
#   'scores': array([210.69498911, 220.61611823])},
#  56516: {'input': ('ecoinvent 3.7.1 cutoff',
#    'bf802d8538688dae8b41584d45efe620'),
#   'output': ('ecoinvent 3.7.1 cutoff', '9cf9a83bcdfd4095b5cc540460e87f6a'),
#   'scores': array([209.82142734, 229.12943932])},
#  58359: {'input': ('ecoinvent 3.7.1 cutoff',
#    '815258d6ec56a4d02c7cb0f2c51748f7'),
#   'output': ('ecoinvent 3.7.1 cutoff', '974bfe6f24ba632db9165b0d4921fd93'),
#   'scores': array([210.77432195, 219.60104925])},
#  60459: {'input': ('ecoinvent 3.7.1 cutoff',
#    'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'output': ('ecoinvent 3.7.1 cutoff', '9a1292f317c992ee77ca094a64baa9ae'),
#   'scores': array([207.46987135, 252.64499925])},
#  60462: {'input': ('ecoinvent 3.7.1 cutoff',
#    'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1e748c3318c71ce855a0a24f446cdb16'),
#   'scores': array([206.05769365, 266.78544703])},
#  60463: {'input': ('ecoinvent 3.7.1 cutoff',
#    'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cee516150ebdd3126b77b893b38ec80d'),
#   'scores': array([178.36092129, 543.7344999 ])},
#  60465: {'input': ('ecoinvent 3.7.1 cutoff',
#    'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'output': ('ecoinvent 3.7.1 cutoff', '668f1f402c19e64319a4e6b024f70760'),
#   'scores': array([208.37660273, 243.60926384])},
#  60467: {'input': ('ecoinvent 3.7.1 cutoff',
#    'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'a4687e27f4665db04bacc0ef8a515379'),
#   'scores': array([207.73707112, 249.97300153])},
#  60600: {'input': ('ecoinvent 3.7.1 cutoff',
#    '130aebbe87868edeafa4e635828bba13'),
#   'output': ('ecoinvent 3.7.1 cutoff', '27bbb6693b714e7943befa8e7699df61'),
#   'scores': array([210.80882092, 219.51128312])},
#  63587: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4c521d9bc70430842f02f7d4fba8766b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([205.87962713, 268.54744149])},
#  63868: {'input': ('ecoinvent 3.7.1 cutoff',
#    'f18ca6d59e49028db78f28c0379a0d2b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '22011a50adadb6b4da46dcb89ec3c5af'),
#   'scores': array([211.18633008, 215.48041197])},
#  65467: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ef21e2bec6f0169f1fda5a58eeedea70'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ec46af09d87335fd68bc35efeabb1193'),
#   'scores': array([211.17152521, 215.62987088])},
#  66127: {'input': ('ecoinvent 3.7.1 cutoff',
#    '14f492a4f9087e2855bb016347c2dca0'),
#   'output': ('ecoinvent 3.7.1 cutoff', '2b0afb5de657179d3f0c74a341dd3f5e'),
#   'scores': array([211.11121198, 216.23188365])},
#  66667: {'input': ('ecoinvent 3.7.1 cutoff',
#    '32d8a4e4b111f994ef14517be440403c'),
#   'output': ('ecoinvent 3.7.1 cutoff', '646cfa14e6c9e77525d798ee672c919c'),
#   'scores': array([211.14283969, 215.91531585])},
#  68052: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b98894a89845c568f15a802da8c7dd82'),
#   'output': ('ecoinvent 3.7.1 cutoff', '16555240574d26ca881283d3a707dbce'),
#   'scores': array([211.25974779, 214.74623484])},
#  68071: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b98894a89845c568f15a802da8c7dd82'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1a31d85af640fe67fb7bceb354a0c1a7'),
#   'scores': array([211.27990743, 214.54463845])},
#  68080: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b98894a89845c568f15a802da8c7dd82'),
#   'output': ('ecoinvent 3.7.1 cutoff', '40b6c42d99a043766c0af118b25d695d'),
#   'scores': array([208.59050841, 241.43862865])},
#  70231: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3989dfd153e795aa734f365ba891fc6d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cee516150ebdd3126b77b893b38ec80d'),
#   'scores': array([210.75597455, 219.78396725])},
#  71354: {'input': ('ecoinvent 3.7.1 cutoff',
#    '82b46dfca0b864b5c97fe7e486400524'),
#   'output': ('ecoinvent 3.7.1 cutoff', '15fb4c7b7e0919aa7930f4c3e4fab20d'),
#   'scores': array([211.17749231, 215.56970876])},
#  74545: {'input': ('ecoinvent 3.7.1 cutoff',
#    '896053cde9aa5117f4b4fa6eca511788'),
#   'output': ('ecoinvent 3.7.1 cutoff', '4e0cb8ba860ea79eac9a7c3c48f261ab'),
#   'scores': array([211.20900884, 215.25362595])},
#  74930: {'input': ('ecoinvent 3.7.1 cutoff',
#    '18bbb16bf0b9bc69eae844f695dd9f9b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '9fa1d4f98aa4f9f56b79122aef930bd7'),
#   'scores': array([210.26217529, 224.7512213 ])},
#  74937: {'input': ('ecoinvent 3.7.1 cutoff',
#    '18bbb16bf0b9bc69eae844f695dd9f9b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ec46af09d87335fd68bc35efeabb1193'),
#   'scores': array([211.13773597, 215.96847315])},
#  75165: {'input': ('ecoinvent 3.7.1 cutoff',
#    '18bbb16bf0b9bc69eae844f695dd9f9b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd22a1a64d97ddd384b72c284a2940868'),
#   'scores': array([211.2415708 , 214.92812134])},
#  75317: {'input': ('ecoinvent 3.7.1 cutoff',
#    '64bec8e92b298b73c28d47a936ab11bb'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cfaba418572499103fa1e3244bf07d98'),
#   'scores': array([211.15538062, 215.79260167])},
#  76423: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2d9dd1e83f105508644251875e73544a'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'db048d933037fa0d6db66f0c8fd2af19'),
#   'scores': array([210.74478477, 220.02634235])},
#  78520: {'input': ('ecoinvent 3.7.1 cutoff',
#    '7b3b68bb3fd4dc861cfa526c18c4b2b8'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([210.88272111, 218.51650163])},
#  83664: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6900ea9c98f611d13d070d534b0078cc'),
#   'output': ('ecoinvent 3.7.1 cutoff', '5f6f08d5f83b0697368c1b4082cd0d7d'),
#   'scores': array([211.11183192, 216.25432714])},
#  84530: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3dc9f01aa4fa3306b1e56ee39a873170'),
#   'output': ('ecoinvent 3.7.1 cutoff', '77a77587077d493bbd733f3e08c378cb'),
#   'scores': array([211.07868576, 216.61990133])},
#  87141: {'input': ('ecoinvent 3.7.1 cutoff',
#    'da9b26e4b24d85552636b0fe55512b5e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6273d44460968ecd729d9f92573081c3'),
#   'scores': array([210.34738613, 223.86985144])},
#  87149: {'input': ('ecoinvent 3.7.1 cutoff',
#    '508a1f2617bb4df24cfd4cedf3b7296b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '23d4ebdfbfe1c36a2f74cb6c4da5f364'),
#   'scores': array([211.2860919, 214.4829143])},
#  90598: {'input': ('ecoinvent 3.7.1 cutoff',
#    '47ab0bb9e2eac0b22d4632992db731f0'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fd52fe7300176a2f2d4520fa0873756f'),
#   'scores': array([211.03190729, 217.02463986])},
#  91217: {'input': ('ecoinvent 3.7.1 cutoff',
#    'e800aba1e3618dfae8b76c5cefe8b0c7'),
#   'output': ('ecoinvent 3.7.1 cutoff', '5e587697dcb330812c9f80d7b8567375'),
#   'scores': array([211.09384194, 216.4321246 ])},
#  92013: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4e81c2995f3d490fdee6378686a9167f'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'afa8bf94b06095d1b59763c995831f98'),
#   'scores': array([211.00144053, 217.32930741])},
#  93629: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a4f661183714d1cf6af079b59d3cd7a0'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f4e0b9029ca47c6e9d454c7cf3af75db'),
#   'scores': array([211.22574459, 215.10040292])},
#  93717: {'input': ('ecoinvent 3.7.1 cutoff',
#    '9be811bee990863f335f60b145c80214'),
#   'output': ('ecoinvent 3.7.1 cutoff', '314b80f8f4f0bb03c1d0aad5cdda8dfa'),
#   'scores': array([211.01351979, 217.25631275])},
#  93759: {'input': ('ecoinvent 3.7.1 cutoff',
#    '73b16ddae17f4bac892962ba7b2b871a'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'e8fdbf87c624b067e4deb05ea56d3758'),
#   'scores': array([211.0827235 , 216.56102597])},
#  94512: {'input': ('ecoinvent 3.7.1 cutoff',
#    '58908ba4d3c61de27100adecc10368aa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f81b1f18430350384e95ec8e34d2631b'),
#   'scores': array([211.28484392, 214.49538315])},
#  97529: {'input': ('ecoinvent 3.7.1 cutoff',
#    '9e2e8d7a526e0eed75739cd154029eb4'),
#   'output': ('ecoinvent 3.7.1 cutoff', '0d15934a8e0bb659af7dd8f65fc0f9fb'),
#   'scores': array([211.26467869, 214.69693523])},
#  97866: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3cb635b7abd0d37ca458fbd4ba9e06d0'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cc8c04a5e95668d0343f36a23fb5bdd1'),
#   'scores': array([211.19049825, 215.44710139])},
#  101307: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ee3f59cca1ef0c8d5d9c7ca572c543ba'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bae7ac36cb8b446ca7f1f0e47c7a10f7'),
#   'scores': array([211.07664174, 216.68796767])},
#  101745: {'input': ('ecoinvent 3.7.1 cutoff',
#    '17b2b72a4d009e7defa79ce7473f8a67'),
#   'output': ('ecoinvent 3.7.1 cutoff', '342e2064251179cda5e58f086ee06c8b'),
#   'scores': array([211.18099936, 215.54801798])},
#  102710: {'input': ('ecoinvent 3.7.1 cutoff',
#    '100f04df4cd10629849821f0499c2de5'),
#   'output': ('ecoinvent 3.7.1 cutoff', '8594c5a9d26f8ceaa9dff72caacaa1db'),
#   'scores': array([211.26223209, 214.73732621])},
#  104474: {'input': ('ecoinvent 3.7.1 cutoff',
#    'e681e62671885f94189511d32daf53f0'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'scores': array([211.157511  , 215.76860278])},
#  107294: {'input': ('ecoinvent 3.7.1 cutoff',
#    '10319806b9a399da2cd16b21768f006f'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6c7fbad2fd63d3cafac9a54eb8e46d25'),
#   'scores': array([209.91915974, 228.18825057])},
#  109461: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6ec79853dfce57106c4a2e6dbaeed0d8'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'c22810fe479468eb8c53cfc31d781326'),
#   'scores': array([211.05885636, 216.75576027])},
#  110263: {'input': ('ecoinvent 3.7.1 cutoff',
#    'c6ef07bb1c000494bc3864f1b6f68eb4'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'b21b16d6afb20b0e23f6f4354a4147f2'),
#   'scores': array([211.27874073, 214.56320055])},
#  110279: {'input': ('ecoinvent 3.7.1 cutoff',
#    '540ef6b7e8cde9ffaf8dc83c664aa0a7'),
#   'output': ('ecoinvent 3.7.1 cutoff', '9fa1d4f98aa4f9f56b79122aef930bd7'),
#   'scores': array([211.17190867, 215.62480333])},
#  110381: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b704baef4fc99e8246acfd5d6f21210a'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6746c58db070b5238e42b3cca9b84d6d'),
#   'scores': array([210.44273694, 222.91701544])},
#  111461: {'input': ('ecoinvent 3.7.1 cutoff',
#    'f5a6568941875ad5def7cb6fea4f2400'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'c53cccc0d98443165b9d6b14861ff487'),
#   'scores': array([211.10425334, 216.30253741])},
#  111998: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b2ab6b881755a2301dbaf239611d9bb3'),
#   'output': ('ecoinvent 3.7.1 cutoff', '143ba68fe272e5a365a07b74b66620e7'),
#   'scores': array([211.16498709, 215.69428831])},
#  112839: {'input': ('ecoinvent 3.7.1 cutoff',
#    '33754bdc65e8f50fa85abf6a65b61f5e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '40b6c42d99a043766c0af118b25d695d'),
#   'scores': array([210.14896071, 225.85410571])},
#  114972: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4398e563be37d5fb2e2dcc4696d9bccc'),
#   'output': ('ecoinvent 3.7.1 cutoff', '30983ca593f5379869b9b7e3f6ccbf65'),
#   'scores': array([211.01895079, 217.15420486])},
#  114974: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4398e563be37d5fb2e2dcc4696d9bccc'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([198.76584689, 339.68524385])},
#  114975: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4398e563be37d5fb2e2dcc4696d9bccc'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([209.60152855, 231.32842729])},
#  115546: {'input': ('ecoinvent 3.7.1 cutoff',
#    'aea4d7fc3db1533a507a6139c1ca1749'),
#   'output': ('ecoinvent 3.7.1 cutoff', '9a19bdf0d0024ebf63cb1ab4f788b78e'),
#   'scores': array([211.1713176 , 215.65563326])},
#  115851: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4058d89f76932a9872fc9031e857a508'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([211.28432467, 214.50046608])},
#  116490: {'input': ('ecoinvent 3.7.1 cutoff',
#    '7b2c639f516785fbf191798be523927e'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ca80cf8daacfc6ee403f93aed1d75986'),
#   'scores': array([211.28245767, 214.51913612])},
#  117223: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b5386d4108e37fe922c3f96fd2471996'),
#   'output': ('ecoinvent 3.7.1 cutoff', '94699d5bdd86f072d148b1474365cf03'),
#   'scores': array([211.27637558, 214.5800879 ])},
#  117660: {'input': ('ecoinvent 3.7.1 cutoff',
#    'e5cf02e1fab89aa4e75ea39cfb3fdffe'),
#   'output': ('ecoinvent 3.7.1 cutoff', '4d182af5974db043f929266df1b4b6f4'),
#   'scores': array([211.09208969, 216.42281585])},
#  117663: {'input': ('ecoinvent 3.7.1 cutoff',
#    'e5cf02e1fab89aa4e75ea39cfb3fdffe'),
#   'output': ('ecoinvent 3.7.1 cutoff', '815e5d29f65df03bec8174e246825355'),
#   'scores': array([204.39643125, 283.37940025])},
#  117668: {'input': ('ecoinvent 3.7.1 cutoff',
#    '1ef3d6617e59c9ebbbc326812aa93c1b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'caaddea9f443b57a4699ab085bd2202e'),
#   'scores': array([210.99655437, 217.37823301])},
#  118171: {'input': ('ecoinvent 3.7.1 cutoff',
#    '4d915ecb57f1363513f4a44e03f5624b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '56bb5a6a8bc206c20928330f3dd082c8'),
#   'scores': array([211.06715335, 216.68782605])},
#  118305: {'input': ('ecoinvent 3.7.1 cutoff',
#    '1a57939b37a5b4ea2bc8404516d2ce19'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ec46af09d87335fd68bc35efeabb1193'),
#   'scores': array([211.25271825, 214.81708479])},
#  120237: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ac5de12561f99c74df1901944605b412'),
#   'output': ('ecoinvent 3.7.1 cutoff', '75b71113798a3835b2efcd7c37c64f1f'),
#   'scores': array([210.74277249, 219.91790891])},
#  120238: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ac5de12561f99c74df1901944605b412'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6a83ce976473a8a68083212f3668e9bd'),
#   'scores': array([209.12048623, 236.13885043])},
#  120632: {'input': ('ecoinvent 3.7.1 cutoff',
#    'faf8370b1b5b7e5cd9d57e896f05fd7c'),
#   'output': ('ecoinvent 3.7.1 cutoff', '23574f8a7d5958515b55b86a612b911d'),
#   'scores': array([211.07273236, 216.61719717])},
#  120633: {'input': ('ecoinvent 3.7.1 cutoff',
#    'faf8370b1b5b7e5cd9d57e896f05fd7c'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'a5108acb672af77a74ace7456fa30810'),
#   'scores': array([211.2728714 , 214.61499932])},
#  120634: {'input': ('ecoinvent 3.7.1 cutoff',
#    'faf8370b1b5b7e5cd9d57e896f05fd7c'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'a82c16fbb822973e32c8f580f1b54ff0'),
#   'scores': array([211.13645737, 215.97922135])},
#  121561: {'input': ('ecoinvent 3.7.1 cutoff',
#    '38b2665c94619e65439a1cda016b3a8d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cee516150ebdd3126b77b893b38ec80d'),
#   'scores': array([211.09465383, 216.39717446])},
#  123154: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ef666597a39d87d5a730b87cde7390b9'),
#   'output': ('ecoinvent 3.7.1 cutoff', '898f8945452d65c76bb6f0f7a38fc51d'),
#   'scores': array([211.19935987, 215.49949779])},
#  128901: {'input': ('ecoinvent 3.7.1 cutoff',
#    '583452528e760dc150d4aac251b0e9ce'),
#   'output': ('ecoinvent 3.7.1 cutoff', '51d3276491f2dc8a28308ffd98ae5b6a'),
#   'scores': array([210.16076197, 225.73609302])},
#  131629: {'input': ('ecoinvent 3.7.1 cutoff',
#    '102f19714262a6ee008f5f120590b652'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([207.11920872, 256.15162551])},
#  131694: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2cd2a5917a489af7a78a9a5077c7435a'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([211.12625095, 216.08120322])},
#  131747: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2cd2a5917a489af7a78a9a5077c7435a'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ca80cf8daacfc6ee403f93aed1d75986'),
#   'scores': array([211.13397438, 216.00396901])},
#  132081: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd98d23d7d3583d1497b2aef6f7ede9eb'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd644e28621a0bba8dc70e9e2d4f43ca0'),
#   'scores': array([211.17066634, 215.68777473])},
#  133614: {'input': ('ecoinvent 3.7.1 cutoff',
#    '15491e9fd6108509babf27e54ddc4ad1'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1a1fc821f3d9dfd450122b4592148e36'),
#   'scores': array([211.17629978, 215.58093737])},
#  133650: {'input': ('ecoinvent 3.7.1 cutoff',
#    '07f51afe387fad243f678d1dec8c0fba'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6bf07d86458308e8812fe3394c6cd8d2'),
#   'scores': array([210.60974969, 221.80642472])},
#  134333: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ac1798bea4ffc50a0334d33d5ed4b61e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '21571f72e0f78bf36a4ebcfb29334386'),
#   'scores': array([211.27758861, 214.57251297])},
#  139270: {'input': ('ecoinvent 3.7.1 cutoff',
#    'af2827ecabb22b85527084edece45341'),
#   'output': ('ecoinvent 3.7.1 cutoff', '3d371e4b6e8c8de56fcd52e085fd7682'),
#   'scores': array([211.09816969, 216.36234003])},
#  139273: {'input': ('ecoinvent 3.7.1 cutoff',
#    'af2827ecabb22b85527084edece45341'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bde2955a6c92726b92e376c543bc2db1'),
#   'scores': array([211.14817475, 215.86255045])},
#  139279: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd5aadd80d718aa3bbaadcc9105d80caa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ff475c54bb184573301593abf0ff923c'),
#   'scores': array([211.2794771 , 214.55301565])},
#  140385: {'input': ('ecoinvent 3.7.1 cutoff',
#    '42c27d1ca1c4dea2e53e31e0e3fad83b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f07adbd21d7ac3e4dc559f4c008daf8a'),
#   'scores': array([210.93903303, 217.95351219])},
#  141958: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8bf4104ef263ec7cbfbcd6aa4802a5ee'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'a8e0a07754ff86849cab6668f9bd46eb'),
#   'scores': array([211.03093134, 217.04195066])},
#  142557: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6c7cf94a202e02fcb5238bac31cb3652'),
#   'output': ('ecoinvent 3.7.1 cutoff', '4453bbc1c3f32686d879085d5473a440'),
#   'scores': array([210.38895855, 223.4779679 ])},
#  147054: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3f7d61d778b6658dd7e7eaf46599b97d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '2fd169388415bb5478d87decb841f238'),
#   'scores': array([211.24240497, 214.9196641 ])},
#  148293: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8f3bb017794dc902c948a1ee6cad8448'),
#   'output': ('ecoinvent 3.7.1 cutoff', '446e5f21110bbe69a5a9e0b2eb06403d'),
#   'scores': array([211.13021726, 216.04670314])},
#  148295: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8f3bb017794dc902c948a1ee6cad8448'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1fd014d963f31f396cb777102feeed65'),
#   'scores': array([211.2614635 , 214.73165372])},
#  148879: {'input': ('ecoinvent 3.7.1 cutoff',
#    'c4397ea0cd808a09a7bf9ba41d9e19fd'),
#   'output': ('ecoinvent 3.7.1 cutoff', '0787383526ca01fce3a61fcf238d36db'),
#   'scores': array([207.14580069, 255.91077645])},
#  149985: {'input': ('ecoinvent 3.7.1 cutoff',
#    '955c9763585494682e96cd6e633ee580'),
#   'output': ('ecoinvent 3.7.1 cutoff', '473d4a436546f2eb4d7e6dfb22c77ccf'),
#   'scores': array([210.87371241, 218.60932477])},
#  150630: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a0128f573e1f03336a2a3e2647cebdc5'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'b98c7b2cc3bfa5d3aac52040013a4b93'),
#   'scores': array([199.45990317, 332.74468102])},
#  150634: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a0128f573e1f03336a2a3e2647cebdc5'),
#   'output': ('ecoinvent 3.7.1 cutoff', '5ee6a71156fcb2ec5765f6346c7b709f'),
#   'scores': array([211.03045707, 217.03914204])},
#  150635: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a0128f573e1f03336a2a3e2647cebdc5'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bfff9fa96558af39d86fa0c297f4c066'),
#   'scores': array([210.83716717, 218.97584931])},
#  151287: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8b69d738d6b61b428acd391c73853452'),
#   'output': ('ecoinvent 3.7.1 cutoff', '15fb4c7b7e0919aa7930f4c3e4fab20d'),
#   'scores': array([211.18009463, 215.54313123])},
#  151766: {'input': ('ecoinvent 3.7.1 cutoff',
#    '619945d955ee9796ea424e80cbce29ae'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ca80cf8daacfc6ee403f93aed1d75986'),
#   'scores': array([211.12773547, 216.06635806])},
#  152140: {'input': ('ecoinvent 3.7.1 cutoff',
#    '7629b22526bcdcd31759d420a1fe2bcc'),
#   'output': ('ecoinvent 3.7.1 cutoff', '3251913f45ceca10764e69d50506a772'),
#   'scores': array([211.20715226, 215.27219013])},
#  155068: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3ab57909163a93fea5c20f8ae26a365a'),
#   'output': ('ecoinvent 3.7.1 cutoff', '03b22c2ecc9399265f1e39e6aeca93bb'),
#   'scores': array([211.26344884, 214.73015498])},
#  155539: {'input': ('ecoinvent 3.7.1 cutoff',
#    '5f40c0472c4d07cb20aea18c81aa6156'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'c6d597bfacf44de8a1811c5ddad128ae'),
#   'scores': array([211.2247546 , 215.11369733])},
#  156362: {'input': ('ecoinvent 3.7.1 cutoff',
#    '87abb24f0b978efccd28442f10155359'),
#   'output': ('ecoinvent 3.7.1 cutoff', '4e33855e245f458646cac2208db42f15'),
#   'scores': array([211.25289188, 214.8157565 ])},
#  160068: {'input': ('ecoinvent 3.7.1 cutoff',
#    'aefdb0411ac9fe391ac2154022fd597e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '678f273f1531b5135a3656955d8cae81'),
#   'scores': array([210.94541801, 217.89019524])},
#  160722: {'input': ('ecoinvent 3.7.1 cutoff',
#    '49a99b6ec194588c17176ea0b4ddb43b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f8e983cfb0b5ac53ae7b8cd91596376e'),
#   'scores': array([211.05261035, 216.81760922])},
#  160933: {'input': ('ecoinvent 3.7.1 cutoff',
#    '37ec4677e40c24060b770a3cb4727023'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([204.17745712, 285.56914159])},
#  161262: {'input': ('ecoinvent 3.7.1 cutoff',
#    '58f98763c9de1dc4ac16f6cd2f6c05f7'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd46a92a4f87ebd40cfa6afcdb6e7f759'),
#   'scores': array([211.164791  , 216.22633711])},
#  161326: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3a0c390b2554e92f8b37236243d5efdb'),
#   'output': ('ecoinvent 3.7.1 cutoff', '57b0634b28e9ce1cecd6aaf21b8e2e8f'),
#   'scores': array([208.53357288, 242.00798399])},
#  162807: {'input': ('ecoinvent 3.7.1 cutoff',
#    '19d22be2ab067f5f682c84e5f1139d57'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1534516e6e27d05e0e8cc93d75bed7a3'),
#   'scores': array([211.11443242, 216.25226513])},
#  162838: {'input': ('ecoinvent 3.7.1 cutoff',
#    '19d22be2ab067f5f682c84e5f1139d57'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd644e28621a0bba8dc70e9e2d4f43ca0'),
#   'scores': array([210.59505821, 221.63467607])},
#  163270: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2050c92f19a64169e943f481614bb1bf'),
#   'output': ('ecoinvent 3.7.1 cutoff', '57b0634b28e9ce1cecd6aaf21b8e2e8f'),
#   'scores': array([211.16613703, 215.68234242])},
#  163391: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2050c92f19a64169e943f481614bb1bf'),
#   'output': ('ecoinvent 3.7.1 cutoff', '5ab3384a5627019dc10f12dd10531cea'),
#   'scores': array([211.28772381, 214.46656279])},
#  164320: {'input': ('ecoinvent 3.7.1 cutoff',
#    'f10b81361286710d9e1072a3748c59c2'),
#   'output': ('ecoinvent 3.7.1 cutoff', '06a6c18fbd208004c9f46a36f168cc4a'),
#   'scores': array([210.16219588, 225.72175394])},
#  164476: {'input': ('ecoinvent 3.7.1 cutoff',
#    '95c6110afdde8e94db8fd617d019da69'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd914569cfeb9d964ad05991cec83f52b'),
#   'scores': array([211.28039962, 214.57179379])},
#  166842: {'input': ('ecoinvent 3.7.1 cutoff',
#    '0e5081e690edd5daef243995fc55389c'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cf798ecbcbcee8bb4a76e5fe490b5999'),
#   'scores': array([210.75369249, 219.8067879 ])},
#  167048: {'input': ('ecoinvent 3.7.1 cutoff',
#    '0e5081e690edd5daef243995fc55389c'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cb8888c3487b9f35ef36edf17ba5c6c1'),
#   'scores': array([211.14401577, 215.91287323])},
#  167938: {'input': ('ecoinvent 3.7.1 cutoff',
#    '2dbd1927fa837138904feba1202d6fe9'),
#   'output': ('ecoinvent 3.7.1 cutoff', '0eafe3b762ad6218fc1350053a969606'),
#   'scores': array([210.99752461, 217.36877518])},
#  168412: {'input': ('ecoinvent 3.7.1 cutoff',
#    '656184caba7a5b36c1bcf992acee1095'),
#   'output': ('ecoinvent 3.7.1 cutoff', '9af7a94542a7330ff858d559a6dee8e2'),
#   'scores': array([210.67405649, 220.69082315])},
#  168477: {'input': ('ecoinvent 3.7.1 cutoff',
#    'f23e214b3ada9fbf0c4e4a1eaf4e4799'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd6f537245190184cd38df27a2c0a067b'),
#   'scores': array([210.67935438, 220.69091949])},
#  168933: {'input': ('ecoinvent 3.7.1 cutoff',
#    '998207ce92bb2ab129750d23022fa5fd'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bb35b0e8cf1655af8aecc0f8589a6ba1'),
#   'scores': array([211.14604222, 215.90953553])},
#  169384: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd9522c5bade327eba4dfb4333e623ffa'),
#   'output': ('ecoinvent 3.7.1 cutoff', '06a6c18fbd208004c9f46a36f168cc4a'),
#   'scores': array([209.66025428, 230.74116992])},
#  169462: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd9522c5bade327eba4dfb4333e623ffa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f8e983cfb0b5ac53ae7b8cd91596376e'),
#   'scores': array([207.73518077, 249.99190505])},
#  169527: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd9522c5bade327eba4dfb4333e623ffa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([210.61379148, 221.205798  ])},
#  171618: {'input': ('ecoinvent 3.7.1 cutoff',
#    'cacc146f945037066500ddaef62fb48c'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fdf8f9780560dc22e47c0c455df36b9a'),
#   'scores': array([211.16719136, 215.67179919])},
#  171794: {'input': ('ecoinvent 3.7.1 cutoff',
#    '67bec9017b54e130747808d3ccc63596'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'ca80cf8daacfc6ee403f93aed1d75986'),
#   'scores': array([211.23542663, 214.98944647])},
#  173082: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8d19deb75d98cc34857a9ff55c683ec5'),
#   'output': ('ecoinvent 3.7.1 cutoff', '349277576409aff6982de10b79b6b9a4'),
#   'scores': array([210.24949479, 224.85142858])},
#  173534: {'input': ('ecoinvent 3.7.1 cutoff',
#    '77422484552f8fa375e85c3833a8f871'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1467e526a365fce63c22b8cb8d088839'),
#   'scores': array([211.03090383, 217.03830597])},
#  174100: {'input': ('ecoinvent 3.7.1 cutoff',
#    '27eece5b770b87c4268ca7f2d024ed53'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fb1edce41f444cdfe97edb9d2f3ec394'),
#   'scores': array([211.25326775, 214.84026514])},
#  174133: {'input': ('ecoinvent 3.7.1 cutoff',
#    '5461d961fea04c7c548f97787e4fee3d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bb35b0e8cf1655af8aecc0f8589a6ba1'),
#   'scores': array([211.1622272 , 215.74678236])},
#  174633: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6a8a150007793dee3da45122d23e94f3'),
#   'output': ('ecoinvent 3.7.1 cutoff', '49fe07ac700a75b43da845ec5d3746b4'),
#   'scores': array([211.11670392, 216.23035009])},
#  174989: {'input': ('ecoinvent 3.7.1 cutoff',
#    'c45569e5a1df432abd08bddbae65163b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '159e7d4a00853af55a5c0dfae592fa14'),
#   'scores': array([211.13674483, 215.98362284])},
#  177429: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3adb75a05e4391411ef02c49a78d8880'),
#   'output': ('ecoinvent 3.7.1 cutoff', '69171ed42bb02dedf1ad8eb32f8742ea'),
#   'scores': array([211.1470388 , 215.87400898])},
#  179318: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6207e631586e755b46d4e5ed387e235f'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cee516150ebdd3126b77b893b38ec80d'),
#   'scores': array([210.78939954, 219.44971732])},
#  183015: {'input': ('ecoinvent 3.7.1 cutoff',
#    '02942a4115cff16989e3c0da7d297450'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'e01a5a7bcb4ef09b11a919768047f5e7'),
#   'scores': array([210.99997099, 217.34455757])},
#  184395: {'input': ('ecoinvent 3.7.1 cutoff',
#    '423e4608a8ec2e17097d320edab30427'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1e748c3318c71ce855a0a24f446cdb16'),
#   'scores': array([211.27561161, 214.58759662])},
#  184408: {'input': ('ecoinvent 3.7.1 cutoff',
#    '423e4608a8ec2e17097d320edab30427'),
#   'output': ('ecoinvent 3.7.1 cutoff', '57b0634b28e9ce1cecd6aaf21b8e2e8f'),
#   'scores': array([210.82659012, 219.07781155])},
#  186959: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a43a52a1a502836621eaa82ad408b17d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'scores': array([209.3752506 , 233.59120679])},
#  187022: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a43a52a1a502836621eaa82ad408b17d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '82c511ea3c17c6ae511b9e0392ae7983'),
#   'scores': array([211.10599637, 216.28374908])},
#  187446: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a43a52a1a502836621eaa82ad408b17d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '619945d955ee9796ea424e80cbce29ae'),
#   'scores': array([210.57591031, 221.5847225 ])},
#  187793: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a43a52a1a502836621eaa82ad408b17d'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'd616a1662572f7cda334390be65fec5d'),
#   'scores': array([211.21206137, 215.22309902])},
#  188039: {'input': ('ecoinvent 3.7.1 cutoff',
#    '89a33338ea9f012c09ca20826eeeb4b6'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'e7b829f39d2c08681dd4b6b236fa3271'),
#   'scores': array([211.15038111, 215.84024118])},
#  188058: {'input': ('ecoinvent 3.7.1 cutoff',
#    '89a33338ea9f012c09ca20826eeeb4b6'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'dfd6a04bfecfda0c8d6719db5aea55ac'),
#   'scores': array([211.23979662, 214.94580491])},
#  188169: {'input': ('ecoinvent 3.7.1 cutoff',
#    '89a33338ea9f012c09ca20826eeeb4b6'),
#   'output': ('ecoinvent 3.7.1 cutoff', '69171ed42bb02dedf1ad8eb32f8742ea'),
#   'scores': array([211.25751463, 214.76873675])},
#  188567: {'input': ('ecoinvent 3.7.1 cutoff',
#    '71d991bacbd82fbf40b830b1d2b2b655'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'de28b2fabaded9de33b5a8cec682098c'),
#   'scores': array([211.18169651, 215.53836752])},
#  189577: {'input': ('ecoinvent 3.7.1 cutoff',
#    'f3c09518aec38c210ebc741439770b6b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '15fb4c7b7e0919aa7930f4c3e4fab20d'),
#   'scores': array([211.0770639 , 216.57336389])},
#  189806: {'input': ('ecoinvent 3.7.1 cutoff',
#    '8aa20e2fbaf1ef65f2deed5ea24dd5bf'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fc5a2a77b493a8b70e8e2107fd3207d5'),
#   'scores': array([210.2376529 , 224.96718378])},
#  190489: {'input': ('ecoinvent 3.7.1 cutoff',
#    '981fbf84043ddd6e1ac40da14f54a96e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1142ae7b27c840608107552b2f190097'),
#   'scores': array([210.47474723, 222.74313403])},
#  193116: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b80aaea062fb0bf98f0782bca31c8a57'),
#   'output': ('ecoinvent 3.7.1 cutoff', '680216cb00938998a70bb14b4110ea09'),
#   'scores': array([209.96586999, 228.11042317])},
#  195260: {'input': ('ecoinvent 3.7.1 cutoff',
#    '5a854e577db61e8b4a9adbda91c2218a'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'c6d597bfacf44de8a1811c5ddad128ae'),
#   'scores': array([211.19969397, 215.3678059 ])},
#  196930: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a739aa4d66d2b7d5a631db2cef048224'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cee516150ebdd3126b77b893b38ec80d'),
#   'scores': array([210.21627395, 225.18097323])},
#  197313: {'input': ('ecoinvent 3.7.1 cutoff',
#    '3d85ee1e3623798960d31ac2bc7f6dca'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([210.56530935, 221.69061931])},
#  199018: {'input': ('ecoinvent 3.7.1 cutoff',
#    'fc8bb3f1a70a3f18f3823e27aee1667d'),
#   'output': ('ecoinvent 3.7.1 cutoff', '12cf38f58ac3e7f9a24c928d80ce88a9'),
#   'scores': array([204.2737334 , 292.78955695])},
#  200970: {'input': ('ecoinvent 3.7.1 cutoff',
#    '92ec1570bab5c44986ac84a6eb0758bd'),
#   'output': ('ecoinvent 3.7.1 cutoff', '40b6c42d99a043766c0af118b25d695d'),
#   'scores': array([211.24933342, 214.85037859])},
#  201847: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ae6f0d8f655d5a2579d83570e58708ec'),
#   'output': ('ecoinvent 3.7.1 cutoff', '06a6c18fbd208004c9f46a36f168cc4a'),
#   'scores': array([211.12846928, 216.05901994])},
#  201858: {'input': ('ecoinvent 3.7.1 cutoff',
#    'ae6f0d8f655d5a2579d83570e58708ec'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f8e983cfb0b5ac53ae7b8cd91596376e'),
#   'scores': array([210.6782197 , 220.56151573])},
#  204661: {'input': ('ecoinvent 3.7.1 cutoff',
#    'efd659f0e71a3f815e40186883b40f3b'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([211.0061357 , 217.28235571])},
#  204662: {'input': ('ecoinvent 3.7.1 cutoff',
#    'efd659f0e71a3f815e40186883b40f3b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([210.6476992 , 220.86672079])},
#  205094: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd4af34aaae9fc5f7c40cdbb3d59cbeda'),
#   'output': ('ecoinvent 3.7.1 cutoff', '2bdd7e0dd0c8e87fc7545a6db644f62a'),
#   'scores': array([210.8251494, 219.0946253])},
#  205468: {'input': ('ecoinvent 3.7.1 cutoff',
#    '5d31573f00e200bfbbe44e4307975799'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bd7e03c54e7e4059343a7863e885b034'),
#   'scores': array([211.24413261, 214.90238664])},
#  205471: {'input': ('ecoinvent 3.7.1 cutoff',
#    '5d31573f00e200bfbbe44e4307975799'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([207.08145759, 256.52913681])},
#  205472: {'input': ('ecoinvent 3.7.1 cutoff',
#    '5d31573f00e200bfbbe44e4307975799'),
#   'output': ('ecoinvent 3.7.1 cutoff', '31a4bbdbd6ea5a3ea81ca20acf93bb51'),
#   'scores': array([208.37810747, 243.56263801])},
#  207092: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6b2b5a9c3f871e031ddf02e9832f7a6b'),
#   'output': ('ecoinvent 3.7.1 cutoff', '84d77fbe6f82bbba6cc0de0a3e101c25'),
#   'scores': array([210.87582464, 218.58760018])},
#  208604: {'input': ('ecoinvent 3.7.1 cutoff',
#    '95b206acb35479aa674670f450de9960'),
#   'output': ('ecoinvent 3.7.1 cutoff', '1c539fe5362870d1eba9983356bc1002'),
#   'scores': array([211.24702426, 214.88665591])},
#  209219: {'input': ('ecoinvent 3.7.1 cutoff',
#    'a16774342df570266e3f7a105a9abffa'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'cf402e20d7b119bd41162a9c65df9b68'),
#   'scores': array([211.24769596, 214.8669526 ])},
#  209637: {'input': ('ecoinvent 3.7.1 cutoff',
#    '606f4c51d59f96ddb2ee99f264e28920'),
#   'output': ('ecoinvent 3.7.1 cutoff', '8594c5a9d26f8ceaa9dff72caacaa1db'),
#   'scores': array([210.60759781, 221.53336069])},
#  209928: {'input': ('ecoinvent 3.7.1 cutoff',
#    '258ff222b063799d98862bee78bfdfc4'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'fcbad706b4bc5fa5e1ba2a06791c88aa'),
#   'scores': array([209.6078537 , 231.26517579])},
#  209947: {'input': ('ecoinvent 3.7.1 cutoff',
#    '258ff222b063799d98862bee78bfdfc4'),
#   'output': ('ecoinvent 3.7.1 cutoff', '82c511ea3c17c6ae511b9e0392ae7983'),
#   'scores': array([211.15510822, 215.79263054])},
#  213481: {'input': ('ecoinvent 3.7.1 cutoff',
#    '1c615a18f45f7174c68044ca98324ddd'),
#   'output': ('ecoinvent 3.7.1 cutoff', '3697d81c55a2f88fca9e4e70b760a482'),
#   'scores': array([211.04239063, 219.88764002])},
#  215121: {'input': ('ecoinvent 3.7.1 cutoff',
#    '6d4bf305a6ef59792673bf3b161d917a'),
#   'output': ('ecoinvent 3.7.1 cutoff', '5dea2d1b85c03dc41b6e8024f3cc34bf'),
#   'scores': array([211.28417705, 214.5055926 ])},
#  216728: {'input': ('ecoinvent 3.7.1 cutoff',
#    'c080373fe39b51ed7de0bbc33b824644'),
#   'output': ('ecoinvent 3.7.1 cutoff', '185d94a0000e87f77eca441439b0e20d'),
#   'scores': array([210.82822641, 219.06144867])},
#  217031: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd346344bde956824a4dbba942f8a880e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '889d1aebc9580dfeb7511dfa7938349a'),
#   'scores': array([211.23242083, 215.01950528])},
#  217237: {'input': ('ecoinvent 3.7.1 cutoff',
#    '57fcca849692d340478d99a4a07f1929'),
#   'output': ('ecoinvent 3.7.1 cutoff', '6273d44460968ecd729d9f92573081c3'),
#   'scores': array([210.96638129, 217.67989984])},
#  220734: {'input': ('ecoinvent 3.7.1 cutoff',
#    '227b698bdbe0cfd3f0230d7315df273f'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'bc79fa219ad3a129be9196801e640eaf'),
#   'scores': array([211.26236811, 214.72003264])},
#  220754: {'input': ('ecoinvent 3.7.1 cutoff',
#    '227b698bdbe0cfd3f0230d7315df273f'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'f267b0c3d8224fa3fd1448eed561e219'),
#   'scores': array([210.72662517, 220.07746111])},
#  222564: {'input': ('ecoinvent 3.7.1 cutoff',
#    '0a0b5d352181626f708d2e6de6bb57f1'),
#   'output': ('ecoinvent 3.7.1 cutoff', 'c997ee0eb7e9ee70f01b3d9de88398b1'),
#   'scores': array([208.42760529, 243.06882576])},
#  230588: {'input': ('ecoinvent 3.7.1 cutoff',
#    'b56e4714fe37262e892d13efb6211cbb'),
#   'output': ('ecoinvent 3.7.1 cutoff', '3bd03c0411efba5d49ca5a0ccba603cc'),
#   'scores': array([207.60673809, 251.27633186])},
#  231047: {'input': ('ecoinvent 3.7.1 cutoff',
#    '218d75770721aa6438f1b8f19bfb5ea3'),
#   'output': ('ecoinvent 3.7.1 cutoff', '45386ec9fbdf9f279e1fb1365a9696c7'),
#   'scores': array([210.91603846, 218.3708081 ])},
#  232488: {'input': ('ecoinvent 3.7.1 cutoff',
#    'd20464840573665d431297c62b3cab90'),
#   'output': ('ecoinvent 3.7.1 cutoff', '7991bbc92a5d04e5f63a7b9856610231'),
#   'scores': array([211.27580671, 214.58732638])},
#  234204: {'input': ('ecoinvent 3.7.1 cutoff',
#    'be4762bc7d9e1444f96209e0e272c45e'),
#   'output': ('ecoinvent 3.7.1 cutoff', '70037ab5947cefde685fdc6fe56bb53b'),
#   'scores': array([210.76152073, 219.73079971])}}

# %%
num_params = 2000
rdict = lca.reverse_dict()[0]
selected_tech_params_sorted = selected_tech_params[np.argsort(uncertainty_measure)[-1::-1][:num_params]]
acts_in = []
acts_out = []
for i,p in enumerate(selected_tech_params_sorted):
    act_in  = bd.get_activity(rdict[p['row']])
    act_out = bd.get_activity(rdict[p['col']])
    acts_in.append(act_in['name'] + act_in['location'])
    acts_out.append(act_out['name'] + act_out['location'])
    print("{} FROM: {}, {}".format(i, act_in['name'], act_in['location']))
    print("    TO:   {}, {}".format(act_out['name'], act_out['location']))
    print("std2mean={:5.4f}, score={:5.4f} \n".format(p['std2mean'], p['contribution']))

# %%
sum(selected_tech_params['contribution'])

# %%
len(set(acts_in))

# %%
selected_tech_params_sorted[4]

# %%
bd.get_activity(rdict[18965])

# %%
# num_params = 50000

# fig = make_subplots(specs=[[{"secondary_y": True}]])
# fig.add_trace(
#     go.Scatter(
#         x=np.arange(num_params),
#         y=selected_tech_params['std2mean'][:num_params],
#         mode="markers",
#         name='std2mean',
#         showlegend=True,
#     ),
#     secondary_y=False,
# )

# fig.add_trace(
#     go.Scatter(
#         x=np.arange(num_params),
#         y=selected_tech_params['contribution'][:num_params],
#         mode="markers",
#         name='contribution',
#         showlegend=True,
#     ),
#     secondary_y=True,
# )
# fig

# fig.update_layout(
# width=1000,
# height=800,
# )
# fig.show()

# %%
ei = bd.Database("ecoinvent 3.7.1 cutoff")
a = [act for act in ei if "electricity voltage transformation from high to medium" in act['name'] and 'CN-SGCC' in act['location']][0]

# %%
e = list(a.exchanges())[1]

# %%
list(a.exchanges())

# %%
e.as_dict()

# %%
input_params[order][:30]

# %%
q_range = 0.95
q_low = (1-q_range)/2
q_high = q_low + q_range
    
s_normal = 0.4
m_normal = 26.148415
s = np.sqrt( (np.exp(s_normal**2)-1) * np.exp(2*m_normal + s_normal**2) )
m = np.exp(m_normal + (s_normal**2)/2)
range_ = ss.lognorm.ppf(q_high,s=s_normal, scale=np.exp(m_normal)) - \
         ss.lognorm.ppf(q_low, s=s_normal, scale=np.exp(m_normal))

# %%
s/m, (s**2)/m, range_ / m

# %%
497270804945.37006  -  103664898722.04993

# %%
range_
